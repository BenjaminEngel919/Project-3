# %% [markdown]
# **Project 3**

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
basics_url="https://datasets.imdbws.com/title.basics.tsv.gz"

ratings_url="https://datasets.imdbws.com/title.ratings.tsv.gz"

akas_url="https://datasets.imdbws.com/title.akas.tsv.gz"

# %%
basics = pd.read_csv(basics_url, sep='\t', low_memory=False)

ratings = pd.read_csv(ratings_url, sep='\t', low_memory=False)

akas = pd.read_csv(akas_url, sep='\t', low_memory=False)

# %%
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1982
# 1  tt0000002            5.8       265
# 2  tt0000003            6.5      1840
# 3  tt0000004            5.5       178
# 4  tt0000005            6.2      2625

# %%
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %%
basics.replace({'\\N':np.nan}, inplace=True)

# %%
ratings.replace({'\\N':np.nan}, inplace=True)

# %%
akas.replace({'\\N':np.nan}, inplace=True)

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe
keepers =basics['tconst'].isin(akas['titleId'])
keepers
# Out:
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 9968611     True
# 9968612     True
# 9968613     True
# 9968614     True
# 9968615    False
# Name: tconst, Length: 9968616, dtype: bool

# %%
basics = basics[keepers]
basics
# Out:
#             tconst  titleType            primaryTitle           originalTitle  \
# 0        tt0000001      short              Carmencita              Carmencita
# 1        tt0000002      short  Le clown et ses chiens  Le clown et ses chiens
# 2        tt0000003      short          Pauvre Pierrot          Pauvre Pierrot
# 3        tt0000004      short             Un bon bock             Un bon bock
# 4        tt0000005      short        Blacksmith Scene        Blacksmith Scene
# ...            ...        ...                     ...                     ...
# 9968610  tt9916846  tvEpisode           Episode #3.18           Episode #3.18
# 9968611  tt9916848  tvEpisode           Episode #3.17           Episode #3.17
# 9968612  tt9916850  tvEpisode           Episode #3.19           Episode #3.19
# 9968613  tt9916852  tvEpisode           Episode #3.20           Episode #3.20
# 9968614  tt9916856      short                The Wind                The Wind
#
#         isAdult startYear endYear runtimeMinutes                    genres
# 0             0      1894     NaN              1         Documentary,Short
# 1             0      1892     NaN              5           Animation,Short
# 2             0      1892     NaN              4  Animation,Comedy,Romance
# 3             0      1892     NaN             12           Animation,Short
# 4             0      1893     NaN              1              Comedy,Short
# ...         ...       ...     ...            ...                       ...
# 9968610       0      2009     NaN            NaN       Action,Drama,Family
# 9968611       0      2009     NaN            NaN       Action,Drama,Family
# 9968612       0      2010     NaN            NaN       Action,Drama,Family
# 9968613       0      2010     NaN            NaN       Action,Drama,Family
# 9968614       0      2015     NaN             27                     Short
#
# [7136910 rows x 9 columns]

# %%
basics = basics.dropna()
basics
# Out:
#             tconst titleType                  primaryTitle  \
# 35177    tt0035803  tvSeries      The German Weekly Review
# 37606    tt0038276  tvSeries             You Are an Artist
# 38440    tt0039120  tvSeries                     Americana
# 38441    tt0039121  tvSeries                Birthday Party
# 38443    tt0039123  tvSeries                 Kraft Theatre
# ...            ...       ...                           ...
# 9967824  tt9915114  tvSeries        Touche pas à mon sport
# 9967833  tt9915138  tvSeries                    Scandalous
# 9967925  tt9915338  tvSeries  Aunty Donna: Camp Bush Camp!
# 9968131  tt9915822  tvSeries            Ichhapyaari Naagin
# 9968310  tt9916216  tvSeries  Kalyanam Mudhal Kadhal Varai
#
#                         originalTitle isAdult startYear endYear  \
# 35177        Die Deutsche Wochenschau       0      1940    1945
# 37606               You Are an Artist       0      1946    1955
# 38440                       Americana       0      1947    1949
# 38441                  Birthday Party       0      1947    1949
# 38443        Kraft Television Theatre       0      1947    1958
# ...                               ...     ...       ...     ...
# 9967824        Touche pas à mon sport       0      2015    2016
# 9967833                    Scandalous       0      2018    2019
# 9967925  Aunty Donna: Camp Bush Camp!       0      2018    2018
# 9968131            Ichhapyaari Naagin       0      2016    2017
# 9968310  Kalyanam Mudhal Kadhal Varai       0      2014    2017
#
#         runtimeMinutes             genres
# 35177               12   Documentary,News
# 37606               15          Talk-Show
# 38440               30   Family,Game-Show
# 38441               30             Family
# 38443               60              Drama
# ...                ...                ...
# 9967824             65    Sport,Talk-Show
# 9967833             60  Crime,Documentary
# 9967925              5             Comedy
# 9968131             20            Fantasy
# 9968310             22            Romance
#
# [50568 rows x 9 columns]

# %%
ratings = ratings.dropna()
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1982
# 1        tt0000002            5.8       265
# 2        tt0000003            6.5      1840
# 3        tt0000004            5.5       178
# 4        tt0000005            6.2      2625
# ...            ...            ...       ...
# 1324795  tt9916730            8.3        10
# 1324796  tt9916766            7.0        21
# 1324797  tt9916778            7.2        36
# 1324798  tt9916840            7.5         7
# 1324799  tt9916880            7.0         7
#
# [1324800 rows x 3 columns]

# %%
akas = akas.dropna()
akas
# Out:
#             titleId  ordering  \
# 103336    tt0022542         1
# 115730    tt0024265         4
# 119214    tt0024751         9
# 128130    tt0026010         3
# 142196    tt0027911         1
# ...             ...       ...
# 34704894  tt9015974         1
# 35110700  tt9248018         3
# 35258055  tt9322538         1
# 35419074  tt9406716         1
# 35910895  tt9667744         5
#
#                                                       title region language  \
# 103336                                Di shtime fun Yisroel     US       yi
# 115730                                     Geleb un gelakht     US       yi
# 119214                                          Avram Ovenu     US       yi
# 128130                              Der yidishe Kenigen Lir     US       yi
# 142196                                   Libe un Laydnshaft     US       yi
# ...                                                     ...    ...      ...
# 34704894                          aşk Üzerine Kısa Bir Film     TR       tr
# 35110700  ODTÜ Tarihi: Bozkırı Yeşertenler ve Zor Yıllar...     TR       tr
# 35258055                                         Aşka Zaman     TR       tr
# 35419074              45. Pantene Altın Kelebek Ödül Töreni     TR       tr
# 35910895                                       Masal çiçeği     TR       tr
#
#                 types             attributes isOriginalTitle
# 103336    alternative       YIVO translation               0
# 115730    alternative     modern translation               0
# 119214    alternative       YIVO translation               0
# 128130    alternative       YIVO translation               0
# 142196    alternative     modern translation               0
# ...               ...                    ...             ...
# 34704894  imdbDisplay           poster title               0
# 35110700  imdbDisplay           poster title               0
# 35258055  imdbDisplay  original script title               0
# 35419074  imdbDisplay              new title               0
# 35910895  imdbDisplay      pre-release title               0
#
# [445 rows x 8 columns]

# %%
basics = basics[basics['startYear'] > '1999']

# %%
basics
# Out:
#             tconst     titleType                                primaryTitle  \
# 108558   tt0111056      tvSeries                          Gensomaden Saiyuki
# 137829   tt0142032  tvMiniSeries                                        Dune
# 153547   tt0158466  tvMiniSeries  Anne of Green Gables: The Continuing Story
# 155739   tt0160904      tvSeries                                        MI-5
# 158606   tt0163944  tvMiniSeries                                  Labyrinten
# ...            ...           ...                                         ...
# 9967824  tt9915114      tvSeries                      Touche pas à mon sport
# 9967833  tt9915138      tvSeries                                  Scandalous
# 9967925  tt9915338      tvSeries                Aunty Donna: Camp Bush Camp!
# 9968131  tt9915822      tvSeries                          Ichhapyaari Naagin
# 9968310  tt9916216      tvSeries                Kalyanam Mudhal Kadhal Varai
#
#                                       originalTitle isAdult startYear endYear  \
# 108558                           Gensomaden Saiyuki       0      2000    2001
# 137829                                         Dune       0      2000    2000
# 153547   Anne of Green Gables: The Continuing Story       0      2000    2000
# 155739                                       Spooks       0      2002    2011
# 158606                                   Labyrinten       0      2000    2000
# ...                                             ...     ...       ...     ...
# 9967824                      Touche pas à mon sport       0      2015    2016
# 9967833                                  Scandalous       0      2018    2019
# 9967925                Aunty Donna: Camp Bush Camp!       0      2018    2018
# 9968131                          Ichhapyaari Naagin       0      2016    2017
# 9968310                Kalyanam Mudhal Kadhal Varai       0      2014    2017
#
#         runtimeMinutes                      genres
# 108558              23  Action,Adventure,Animation
# 137829             265      Adventure,Drama,Sci-Fi
# 153547             185        Drama,Family,Romance
# 155739              60          Action,Crime,Drama
# 158606             259              Drama,Thriller
# ...                ...                         ...
# 9967824             65             Sport,Talk-Show
# 9967833             60           Crime,Documentary
# 9967925              5                      Comedy
# 9968131             20                     Fantasy
# 9968310             22                     Romance
#
# [31802 rows x 9 columns]

# %%
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1982
# 1        tt0000002            5.8       265
# 2        tt0000003            6.5      1840
# 3        tt0000004            5.5       178
# 4        tt0000005            6.2      2625
# ...            ...            ...       ...
# 1324795  tt9916730            8.3        10
# 1324796  tt9916766            7.0        21
# 1324797  tt9916778            7.2        36
# 1324798  tt9916840            7.5         7
# 1324799  tt9916880            7.0         7
#
# [1324800 rows x 3 columns]

# %%
akas
# Out:
#             titleId  ordering  \
# 103336    tt0022542         1
# 115730    tt0024265         4
# 119214    tt0024751         9
# 128130    tt0026010         3
# 142196    tt0027911         1
# ...             ...       ...
# 34704894  tt9015974         1
# 35110700  tt9248018         3
# 35258055  tt9322538         1
# 35419074  tt9406716         1
# 35910895  tt9667744         5
#
#                                                       title region language  \
# 103336                                Di shtime fun Yisroel     US       yi
# 115730                                     Geleb un gelakht     US       yi
# 119214                                          Avram Ovenu     US       yi
# 128130                              Der yidishe Kenigen Lir     US       yi
# 142196                                   Libe un Laydnshaft     US       yi
# ...                                                     ...    ...      ...
# 34704894                          aşk Üzerine Kısa Bir Film     TR       tr
# 35110700  ODTÜ Tarihi: Bozkırı Yeşertenler ve Zor Yıllar...     TR       tr
# 35258055                                         Aşka Zaman     TR       tr
# 35419074              45. Pantene Altın Kelebek Ödül Töreni     TR       tr
# 35910895                                       Masal çiçeği     TR       tr
#
#                 types             attributes isOriginalTitle
# 103336    alternative       YIVO translation               0
# 115730    alternative     modern translation               0
# 119214    alternative       YIVO translation               0
# 128130    alternative       YIVO translation               0
# 142196    alternative     modern translation               0
# ...               ...                    ...             ...
# 34704894  imdbDisplay           poster title               0
# 35110700  imdbDisplay           poster title               0
# 35258055  imdbDisplay  original script title               0
# 35419074  imdbDisplay              new title               0
# 35910895  imdbDisplay      pre-release title               0
#
# [445 rows x 8 columns]

# %%
# Exclude movies that are included in the documentary category.
is_documentary = basics['genres'].str.contains('documentary',case=False)
basics = basics[~is_documentary]

# %%
basics
# Out:
#             tconst     titleType                                primaryTitle  \
# 108558   tt0111056      tvSeries                          Gensomaden Saiyuki
# 137829   tt0142032  tvMiniSeries                                        Dune
# 153547   tt0158466  tvMiniSeries  Anne of Green Gables: The Continuing Story
# 155739   tt0160904      tvSeries                                        MI-5
# 158606   tt0163944  tvMiniSeries                                  Labyrinten
# ...            ...           ...                                         ...
# 9967791  tt9915022      tvSeries                               Yarali Kuslar
# 9967824  tt9915114      tvSeries                      Touche pas à mon sport
# 9967925  tt9915338      tvSeries                Aunty Donna: Camp Bush Camp!
# 9968131  tt9915822      tvSeries                          Ichhapyaari Naagin
# 9968310  tt9916216      tvSeries                Kalyanam Mudhal Kadhal Varai
#
#                                       originalTitle isAdult startYear endYear  \
# 108558                           Gensomaden Saiyuki       0      2000    2001
# 137829                                         Dune       0      2000    2000
# 153547   Anne of Green Gables: The Continuing Story       0      2000    2000
# 155739                                       Spooks       0      2002    2011
# 158606                                   Labyrinten       0      2000    2000
# ...                                             ...     ...       ...     ...
# 9967791                               Yarali Kuslar       0      2019    2019
# 9967824                      Touche pas à mon sport       0      2015    2016
# 9967925                Aunty Donna: Camp Bush Camp!       0      2018    2018
# 9968131                          Ichhapyaari Naagin       0      2016    2017
# 9968310                Kalyanam Mudhal Kadhal Varai       0      2014    2017
#
#         runtimeMinutes                      genres
# 108558              23  Action,Adventure,Animation
# 137829             265      Adventure,Drama,Sci-Fi
# 153547             185        Drama,Family,Romance
# 155739              60          Action,Crime,Drama
# 158606             259              Drama,Thriller
# ...                ...                         ...
# 9967791             90                       Drama
# 9967824             65             Sport,Talk-Show
# 9967925              5                      Comedy
# 9968131             20                     Fantasy
# 9968310             22                     Romance
#
# [25645 rows x 9 columns]

# %%
basics = basics[basics['titleType'] == 'movie']

# %%
basics
# Out:
# Empty DataFrame
# Columns: [tconst, titleType, primaryTitle, originalTitle, isAdult, startYear, endYear, runtimeMinutes, genres]
# Index: []

# %%
# example making new folder with os
import os
os.makedirs('Data/',exist_ok=True) 
# Confirm folder created
os.listdir("Data/")
# Out:
# ['.ipynb_checkpoints']

# %%
## Save current dataframe to file.
basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
basics = pd.read_csv("Data/title_basics.csv.gz", low_memory = False)
basics.head()
# Out:
# Empty DataFrame
# Columns: [tconst, titleType, primaryTitle, originalTitle, isAdult, startYear, endYear, runtimeMinutes, genres]
# Index: []

# %%
## Save current dataframe to file
ratings.to_csv("Data/title_ratings.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
ratings = pd.read_csv("Data/title_ratings.csv.gz", low_memory = False)
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1982
# 1  tt0000002            5.8       265
# 2  tt0000003            6.5      1840
# 3  tt0000004            5.5       178
# 4  tt0000005            6.2      2625

# %%
## Save current dataframe to file
akas.to_csv("Data/title_akas.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
akas = pd.read_csv("Data/title_akas.csv.gz", low_memory = False)
akas.head()
# Out:
#      titleId  ordering                    title region language        types  \
# 0  tt0022542         1    Di shtime fun Yisroel     US       yi  alternative
# 1  tt0024265         4         Geleb un gelakht     US       yi  alternative
# 2  tt0024751         9              Avram Ovenu     US       yi  alternative
# 3  tt0026010         3  Der yidishe Kenigen Lir     US       yi  alternative
# 4  tt0027911         1       Libe un Laydnshaft     US       yi  alternative
#
#            attributes  isOriginalTitle
# 0    YIVO translation                0
# 1  modern translation                0
# 2    YIVO translation                0
# 3    YIVO translation                0
# 4  modern translation                0
